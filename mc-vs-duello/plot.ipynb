# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.offsetbox import OffsetImage, AnnotationBbox
from PIL import Image

# %%
def com_distance_to_pmf(file, bins):
    """Load COM distance as a function of MC steps and calculate potential of mean forece (PMF)"""
    p, r = np.histogram(np.loadtxt(file), bins=bins)
    r = r[1:] / 2 + r[0:-1] / 2
    dr = r[1] - r[0]
    r_max = r[-1]
    gofr = p / p.sum() * r_max / dr  # g(r)
    pmf = -np.log(gofr)  # w(r)/kT
    print(f"r_min = {r[0]}, r_max = {r_max} Å, dr = {dr} Å")
    return r, pmf

# %%
fig, ax = plt.subplots(nrows=1, figsize=(7, 3))
r, pmf = com_distance_to_pmf("com_distance.dat.gz", bins=100)
ax.hlines(0, xmin=r[0] - 10, xmax=r[-1] + 10, color="k", alpha=0.5, ls="--", lw=2)
ax.plot(
    r,
    pmf - 0.7,
    "bo",
    lw=3,
    label="Monte-Carlo simulation (wall-time 120 sec)",
    alpha=0.7,
    ms=4,
)

r, pmf = np.loadtxt("duello-pmf.dat", usecols=[0, 1], unpack=True)
ax.plot(
    r, pmf, label=r"Duello $n_d=1$ (wall-time 10 sec)", lw=2, alpha=0.8, color="red"
)

ax.set_ylabel("Free energy ($k_BT$)")
ax.set_xlabel("Mass center separation, $R$ (Å)")
ax.legend(loc=0, frameon=False)
ax.set_xlim(37, 95)
ax.set_ylim(-4.2, 4)

image = Image.open("cppm-model.png")
imagebox = OffsetImage(
    image, zoom=0.12
)  # zoom scales the image while keeping aspect ratio
ab = AnnotationBbox(imagebox, (75, -2), frameon=False)  # position (x, y)
ax.add_artist(ab)
ax.annotate("A", xy=(40, 3.2), fontsize="x-large", fontweight="bold")
ax.text(70, 1.1, "ion-ion repulsion", rotation=-3, fontstyle="italic", fontsize="large")
ax.text(
    46,
    -3.5,
    "ion-dipole\nattraction",
    rotation=45,
    fontstyle="italic",
    fontsize="large",
)
plt.savefig("mc-vs-duello.png", bbox_inches="tight", dpi=300)
plt.show()
# Out:
# r_min = 38.334505, r_max = 105.75449499999999 Å, dr = 0.6810100000000006 Å

# %%
#Plot for Poster
fig, ax = plt.subplots(nrows=1, figsize=(7, 3))
r, pmf = com_distance_to_pmf("com_distance.dat.gz", bins=100)
ax.hlines(0, xmin=r[0]-10, xmax=r[-1]+10, color='k', alpha=0.5, ls='--', lw=1)
ax.plot(r, pmf - 0.7, 'o', lw=3, label="Monte-Carlo simulation (wall-time 120 sec)", alpha=1, ms=4, color='#5C9BA1')

r, pmf = np.loadtxt("duello-pmf.dat", usecols=[0,1], unpack=True)
ax.plot(r, pmf, label=r"Duello $n_d=1$ (wall-time 10 sec CPU; 1 sec GPU)", lw=1, alpha=0.9, color='grey')

ax.set_ylabel("Free energy ($k_BT$)")
# Move it to the top
#ax.yaxis.set_label_coords(0.0, 1.02)
ax.set_xlabel("Mass center separation, $R$ (Å)")
ax.legend(loc=0, frameon=False)
ax.set_xlim(37, 95)
ax.set_ylim(-4.2, 4)

for spine in ax.spines.values():
    spine.set_color("0.55")
    spine.set_linewidth(0.8)

image = Image.open('cppm_model_upscaled.png')
imagebox = OffsetImage(image, zoom=0.015)  # zoom scales the image while keeping aspect ratio
ab = AnnotationBbox(imagebox, (75, -2), frameon=False)  # position (x, y)
ax.add_artist(ab)
#ax.annotate("A", xy=(40, 3.2), fontsize='x-large', fontweight='bold')
ax.text(70, 1.3, "ion-ion repulsion", rotation=0, fontstyle='italic', fontsize='large')
ax.text(48, -2.5, "ion-dipole\nattraction", rotation=0, fontstyle='italic', fontsize='large')
ax.text(75, -3.5, "two-body model", rotation=0, fontstyle='italic', fontsize='large')
plt.savefig("mc-vs-duello.svg", format='svg', bbox_inches="tight", dpi=1000)
plt.show()
# Out:
# r_min = 38.334505, r_max = 105.75449499999999 Å, dr = 0.6810100000000006 Å
