# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
for i in [0,1,2,3,4,10]:
    n = np.loadtxt(f"weights-n{i}")
    n = np.sort(n)
    
    print(i, n.mean(), n.std())
    plt.plot(n)
# Out:
# 0 0.9999999999999999 0.0
# 1 0.9999999999999997 0.02700542070483876
# 2 1.0 0.02763354708719851
# 3 0.9999999999999993 0.045885080500657136
# 4 0.9999999999999999 0.0431241030979535
# 10 0.9999999999999989 0.026008576360446428
