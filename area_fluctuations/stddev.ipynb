# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
for i in range(11):
    n = np.loadtxt(f"weights-n{i}")
    n = np.sort(n)
    
    print("{:3} {:.2f} {:.3f}".format(i, n.mean(), n.std()))
    plt.plot(n)
# Out:
#   0 1.00 0.000
#   1 1.00 0.027
#   2 1.00 0.028
#   3 1.00 0.046
#   4 1.00 0.043
#   5 1.00 0.037
#   6 1.00 0.033
#   7 1.00 0.030
#   8 1.00 0.028
#   9 1.00 0.027
#  10 1.00 0.026
